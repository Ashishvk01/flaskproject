# %%
#we all know how to import packages
import math
import numpy as np #using alias
from math import sqrt #using only the function

print(math.sqrt(5))
print(sqrt(9))

#what if i wanted to import all the functions of a perticular package
from math import *
acosh(90)
# Out:
# 2.23606797749979
# 3.0
# 5.192925985263684

# %% [markdown]
# how to create/axcess your own packages
#
# step1 : go to the folder which you are present in and add _init_.py file you can keep it blank.If
#         you what to know why just check content the file.
#
# step2 : now create a file with all the functions or if you have one very good.(functions.py here)
#
# step3 :use method below method to axess the file

# %%
# from packages_modules_libraries.functions import addition
# print(addition(3,3))   
# use this when you are outside the folder

from functions import addition
print(addition(3,3))
# Out:
# 6

# %% [markdown]
# check test.py if you want to know how to call them in the .py file

# %%
#in order to test the theory from other folders 
#lets create a folder called subfold and inside it create another folder subfold1
#create an init file and a functions file and try to axcess it from here 

from subfold.subfold1.function import multipy
multipy(100,2)
# Out:
# 200
